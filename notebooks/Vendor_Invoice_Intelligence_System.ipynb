# %% [markdown]
# # VENDOR INVOICE INTELLIGENCE SYSTEM
# ___________________________________________________
# ## Freight Cost Prediction & Invoice Risk Flagging
#
# - Business Problem: Invoice Cost Leakage & Audit Risk
# - Business Objectives: Predict Freight Cost & Flag Risky Invoices
# - Data Sources: inventory.db
# - SQL Feature Engineering: Invoice-Level Aggregations
# - EDA & Analysis: Cost Patterns, Risk Behavior, T-tests
# - Modeling:
# 1. Freight Cost Prediction (Regression Models)
# 2. Invoice Risk Flagging (Classification Models)
# - Model Evaluation: MAE|RSME|R^2    Precision|Recall|F1-Score
# - Model Deployment: Streamlit Application (.pkl Files)
